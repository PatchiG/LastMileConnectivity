# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishsalunkhe/LastMileConnectivity/blob/main/transitAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# List of major locations (latitude and longitude) in the DMV region
locations = [
    {"name": "Washington, DC", "lat": 38.89511, "lon": -77.03637},
    {"name": "Silver Spring, MD", "lat": 38.9907, "lon": -77.0261},
    {"name": "Bethesda, MD", "lat": 39.0047, "lon": -77.1003},
    {"name": "Arlington, VA", "lat": 38.8875, "lon": -77.0981},
    {"name": "Alexandria, VA", "lat": 38.8048, "lon": -77.0469},
    {"name": "College Park, MD", "lat": 38.9794, "lon": -76.9378},
    {"name": "Fairfax, VA", "lat": 38.8462, "lon": -77.3064},
    {"name": "Rockville, MD", "lat": 39.0840, "lon": -77.1528},
    {"name": "Gaithersburg, MD", "lat": 39.1434, "lon": -77.2014},
    {"name": "Vienna, VA", "lat": 38.9010, "lon": -77.2659},
    {"name": "Reston, VA", "lat": 38.9587, "lon": -77.3570},
    {"name": "Greenbelt, MD", "lat": 39.0025, "lon": -76.8842},
    {"name": "Hyattsville, MD", "lat": 38.9677, "lon": -76.9500},
    {"name": "Laurel, MD", "lat": 39.0995, "lon": -76.8482},
    {"name": "Silver Spring Metro, MD", "lat": 38.9905, "lon": -77.0258},
    {"name": "Chantilly, VA", "lat": 38.8797, "lon": -77.4445},
    {"name": "Bethesda Metro, MD", "lat": 39.0037, "lon": -77.0981},
    {"name": "Falls Church, VA", "lat": 38.8844, "lon": -77.1734},
    {"name": "Landover, MD", "lat": 38.9534, "lon": -76.8950},
    {"name": "Mclean, VA", "lat": 38.9330, "lon": -77.1797}
]

# Function to get placemarks for a location
def get_placemarks(api_key, lat, lon, distance=500):
    url = "https://external.transitapp.com/v3/map_layers/placemarks"
    params = {
        "lat": lat,
        "lon": lon,
        "distance": distance,
        "apiKey": api_key
    }

    # Make the API request
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Function to get placemarks for the top 20 locations
def get_all_placemarks(api_key):
    placemarks_by_location = {}

    for location in locations:
        name = location["name"]
        lat = location["lat"]
        lon = location["lon"]

        print(f"Fetching placemarks for {name}...")

        # Get placemarks for the location
        placemarks = get_placemarks(api_key, lat, lon)

        if "error" not in placemarks:
            placemarks_by_location[name] = placemarks.get('placemarks', [])
        else:
            placemarks_by_location[name] = placemarks['error']

    return placemarks_by_location

# Example usage
api_key = "###"
placemarks_data = get_all_placemarks(api_key)

# Printing placemarks for each location
for location, placemarks in placemarks_data.items():
    print(f"\nPlacemarks for {location}:")
    if isinstance(placemarks, list) and placemarks:
        for placemark in placemarks:
            print(placemark)
    else:
        print(placemarks)
# Out:
# Fetching placemarks for Washington, DC...
# Fetching placemarks for Silver Spring, MD...
# Fetching placemarks for Bethesda, MD...
# Fetching placemarks for Arlington, VA...
# Fetching placemarks for Alexandria, VA...
# Fetching placemarks for College Park, MD...
# Fetching placemarks for Fairfax, VA...
# Fetching placemarks for Rockville, MD...
# Fetching placemarks for Gaithersburg, MD...
# Fetching placemarks for Vienna, VA...
# Fetching placemarks for Reston, VA...
# Fetching placemarks for Greenbelt, MD...
# Fetching placemarks for Hyattsville, MD...
# Fetching placemarks for Laurel, MD...
# Fetching placemarks for Silver Spring Metro, MD...
# Fetching placemarks for Chantilly, VA...
# Fetching placemarks for Bethesda Metro, MD...
# Fetching placemarks for Falls Church, VA...
# Fetching placemarks for Landover, MD...
# Fetching placemarks for Mclean, VA...
#
# Placemarks for Washington, DC:
# Failed to retrieve data: 401
#
# Placemarks for Silver Spring, MD:
# ...

# %%
import requests

# Example location: Washington, DC (latitude and longitude)
lat = 45.526168077787894
lon = -73.59506067289408

# Your API key (replace with your actual key)
api_key = "26a4802541a273dc8dc977f1309ce1947d83b646ac8f15c0b6ec1948dde22248"

# Function to get placemarks for a specific location
def get_placemarks(api_key, lat, lon, distance=500):
    url = "https://external.transitapp.com/v3/map_layers/placemarks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    params = {
        "lat": lat,
        "lon": lon,
        "distance": distance
    }

    # Make the API request with header
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        print(response.json())
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Get placemarks for Washington, DC
placemarks = get_placemarks(api_key, lat, lon)

# Print placemarks or error
if "error" in placemarks:
    print(placemarks["error"])
else:
    print("Placemarks for Washington, DC:")
    for placemark in placemarks.get('placemarks', []):
        print(placemark)
# Out:
# {'placemarks': [{'title': 'St-Viateur / Casgrain', 'subtitle': '3 bikes and 20 docks', 'id': '532', 'networkName': 'BIXI', 'networkId': 1030, 'color': 'e9473f', 'textColor': 'FFFFFF', 'latitude': 45.52707134397896, 'longitude': -73.5979351401329, 'type': 'station', 'stationProperties': {'counts': {'bike': 3, 'dock': 20}}}, {'title': 'Laurier / St-Denis', 'subtitle': '22 bikes and 15 docks', 'id': '558', 'networkName': 'BIXI', 'networkId': 1030, 'color': 'e9473f', 'textColor': 'FFFFFF', 'latitude': 45.5271540234837, 'longitude': -73.58943924307823, 'type': 'station', 'stationProperties': {'counts': {'bike': 22, 'dock': 15}}}]}
# Placemarks for Washington, DC:
# {'title': 'St-Viateur / Casgrain', 'subtitle': '3 bikes and 20 docks', 'id': '532', 'networkName': 'BIXI', 'networkId': 1030, 'color': 'e9473f', 'textColor': 'FFFFFF', 'latitude': 45.52707134397896, 'longitude': -73.5979351401329, 'type': 'station', 'stationProperties': {'counts': {'bike': 3, 'dock': 20}}}
# ...

# %%
# Function to get available sharing system networks
def get_available_networks(api_key):
    url = "https://external.transitapp.com/v3/map_layers/available_networks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    # Make the API request with header
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Fetch and print available sharing system networks
networks = get_available_networks(api_key)

# Print the networks or error message
if "error" in networks:
    print(networks["error"])
else:
    print("Available Sharing System Networks:")
    for network in networks.get('networks', []):
        print(network)
# Out:
# Available Sharing System Networks:
# {'network_id': 2, 'network_name': 'Citi Bike', 'network_geometry': {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[-74.16047289563079, 40.52734525609407], [-73.71562983521406, 40.52734525609407], [-73.71562983521406, 41.00688209763853], [-74.16047289563079, 41.00688209763853], [-74.16047289563079, 40.52734525609407]]]}, 'properties': {}}, 'network_color': '2E4DA7'}
# {'network_id': 3, 'network_name': 'Vélhop', 'network_geometry': {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[7.6985, 48.5148], [7.8083, 48.5148], [7.8083, 48.6432], [7.6985, 48.6432], [7.6985, 48.5148]]]}, 'properties': {}}, 'network_color': '1234AA'}
# ...

# %%
import csv


# Function to get available sharing system networks
def get_available_networks(api_key):
    url = "https://external.transitapp.com/v3/map_layers/available_networks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    # Make the API request with header
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Function to write networks to a CSV
def write_networks_to_csv(networks, filename='networks.csv'):
    # Define the CSV header
    header = ['network_id', 'network_name', 'network_color', 'coordinates']

    # Open the CSV file for writing
    with open(filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(header)  # Write header row

        # Loop through each network in the response
        for network in networks.get('networks', []):
            # Extract the necessary information
            network_id = network.get('network_id', '')
            network_name = network.get('network_name', '')
            network_color = network.get('network_color', '')
            coordinates = network.get('network_geometry', {}).get('geometry', {}).get('coordinates', [])

            # Flatten the coordinates for CSV
            coords_flat = str(coordinates)  # Convert list of coordinates to string

            # Write the network details to the CSV
            writer.writerow([network_id, network_name, network_color, coords_flat])

# Fetch available networks
networks = get_available_networks(api_key)

# Handle error if the API call fails
if "error" in networks:
    print(networks["error"])
else:
    # Write the networks data to a CSV file
    write_networks_to_csv(networks)
    print("Networks data has been written to networks.csv")
# Out:
# Networks data has been written to networks.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('networks.csv')

# %%
df.head()
# Out:
#    network_id        network_name network_color  \
# 0           2           Citi Bike        2E4DA7
# 1           3              Vélhop        1234AA
# 2        1025  Bike Share Toronto        107054
# 3           6          Blue Bikes        2CA3E2
# 4           7        VélÔToulouse        B4101C
#
#                                          coordinates
# 0  [[[-74.16047289563079, 40.52734525609407], [-7...
# 1  [[[7.6985, 48.5148], [7.8083, 48.5148], [7.808...
# 2  [[[-79.6092, 43.558], [-79.0602, 43.558], [-79...
# 3  [[[-71.1905, 42.2474], [-70.982, 42.2474], [-7...
# 4  [[[0.4069, 43.3604], [1.6288, 43.3604], [1.628...

# %%
df.shape
# Out:
# (301, 4)

# %%
import requests
import folium

# Function to get available sharing system networks
def get_available_networks(api_key):
    url = "https://external.transitapp.com/v3/map_layers/available_networks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    # Make the API request with header
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Function to plot coordinates on a map
def plot_coordinates_on_map(networks):
    # Create a map centered around a default location (latitude, longitude)
    m = folium.Map(location=[40.730610, -73.935242], zoom_start=12)

    # Loop through each network in the response
    for network in networks.get('networks', []):
        # Extract the network name and coordinates
        network_name = network.get('network_name', 'Unknown Network')
        coordinates = network.get('network_geometry', {}).get('geometry', {}).get('coordinates', [])

        if coordinates:
            # Loop through the coordinates and plot them
            for coordinate in coordinates:
                # Coordinates are in the form [longitude, latitude]
                for point in coordinate:
                    # Add a marker for each coordinate
                    folium.Marker(location=[point[1], point[0]], popup=network_name).add_to(m)

    # Save the map to an HTML file
    m.save("networks_map.html")
    print("Map has been saved to networks_map.html")

# Fetch available networks
networks = get_available_networks(api_key)

# Handle error if the API call fails
if "error" in networks:
    print(networks["error"])
else:
    # Plot coordinates on the map
    plot_coordinates_on_map(networks)
# Out:
# Map has been saved to networks_map.html

# %%
import requests

# Your API key (replace with your actual key)
api_key = "###"

# List of top 20 locations in the DMV area with latitude and longitude
locations = [
    ("Washington, DC", 38.9076, -77.0365),  # Washington, DC
    ("Bethesda, MD", 39.0040, -77.0890),   # Bethesda, MD
    ("Silver Spring, MD", 38.9907, -77.0261),  # Silver Spring, MD
    ("Arlington, VA", 38.8870, -77.0941),  # Arlington, VA
    ("Alexandria, VA", 38.8048, -77.0469),  # Alexandria, VA
    ("Rockville, MD", 39.0836, -77.1528),   # Rockville, MD
    ("Gaithersburg, MD", 39.1434, -77.2013),  # Gaithersburg, MD
    ("Tysons, VA", 38.9277, -77.2210),      # Tysons, VA
    ("Fairfax, VA", 38.8462, -77.3064),     # Fairfax, VA
    ("McLean, VA", 38.9331, -77.1793),      # McLean, VA
    ("Falls Church, VA", 38.8816, -77.1747),  # Falls Church, VA
    ("Vienna, VA", 38.9010, -77.2630),      # Vienna, VA
    ("College Park, MD", 38.9867, -76.9378),  # College Park, MD
    ("Greenbelt, MD", 39.0028, -76.8756),    # Greenbelt, MD
    ("Hyattsville, MD", 38.9680, -76.9480),  # Hyattsville, MD
    ("Laurel, MD", 39.0997, -76.8483),      # Laurel, MD
    ("Bowie, MD", 38.9837, -76.7792),       # Bowie, MD
    ("Chantilly, VA", 38.8790, -77.4426),    # Chantilly, VA
    ("Reston, VA", 38.9587, -77.3570),      # Reston, VA
    ("Manassas, VA", 38.7509, -77.4753)      # Manassas, VA
]

# Function to get placemarks for a specific location
def get_placemarks(api_key, lat, lon, distance=500):
    url = "https://external.transitapp.com/v3/map_layers/placemarks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    params = {
        "lat": lat,
        "lon": lon,
        "distance": distance
    }

    # Make the API request with header
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# Fetch placemarks for top 20 DMV locations
for location, lat, lon in locations:
    print(f"Fetching placemarks for {location} (Lat: {lat}, Lon: {lon})...")

    placemarks = get_placemarks(api_key, lat, lon)

    # Print placemarks or error
    if "error" in placemarks:
        print(placemarks["error"])
    else:
        print(f"Placemarks for {location}:")
        for placemark in placemarks.get('placemarks', []):
            print(f"- {placemark}")
        print("\n" + "-"*50 + "\n")
# Out:
# Fetching placemarks for Washington, DC (Lat: 38.9076, Lon: -77.0365)...
# Placemarks for Washington, DC:
# - {'title': '17th St / Massachusetts Ave NW', 'subtitle': '7 bikes, 1 e-bike, and 12 docks', 'id': '08255063-1f3f-11e7-bf6b-3863bb334450', 'networkName': 'Capital Bikeshare', 'networkId': 12, 'color': 'EE3124', 'textColor': 'FFFFFF', 'latitude': 38.908568, 'longitude': -77.038542, 'type': 'station', 'stationProperties': {'counts': {'bike': 7, 'electric-bike': 1, 'dock': 12}}}
# - {'title': '15th / P St NW', 'subtitle': '12 bikes and 7 docks', 'id': '0824791a-1f3f-11e7-bf6b-3863bb334450', 'networkName': 'Capital Bikeshare', 'networkId': 12, 'color': 'EE3124', 'textColor': 'FFFFFF', 'latitude': 38.90980062655191, 'longitude': -77.03442692756653, 'type': 'station', 'stationProperties': {'counts': {'bike': 12, 'dock': 7}}}
# ...

# %%
import requests
import csv

# Your API key (replace with your actual key)
api_key = "###"

# List of top 20 locations in the DMV area with latitude and longitude
locations = [
    ("Washington, DC", 38.9076, -77.0365),  # Washington, DC
    ("Bethesda, MD", 39.0040, -77.0890),   # Bethesda, MD
    ("Silver Spring, MD", 38.9907, -77.0261),  # Silver Spring, MD
    ("Arlington, VA", 38.8870, -77.0941),  # Arlington, VA
    ("Alexandria, VA", 38.8048, -77.0469),  # Alexandria, VA
    ("Rockville, MD", 39.0836, -77.1528),   # Rockville, MD
    ("Gaithersburg, MD", 39.1434, -77.2013),  # Gaithersburg, MD
    ("Tysons, VA", 38.9277, -77.2210),      # Tysons, VA
    ("Fairfax, VA", 38.8462, -77.3064),     # Fairfax, VA
    ("McLean, VA", 38.9331, -77.1793),      # McLean, VA
    ("Falls Church, VA", 38.8816, -77.1747),  # Falls Church, VA
    ("Vienna, VA", 38.9010, -77.2630),      # Vienna, VA
    ("College Park, MD", 38.9867, -76.9378),  # College Park, MD
    ("Greenbelt, MD", 39.0028, -76.8756),    # Greenbelt, MD
    ("Hyattsville, MD", 38.9680, -76.9480),  # Hyattsville, MD
    ("Laurel, MD", 39.0997, -76.8483),      # Laurel, MD
    ("Bowie, MD", 38.9837, -76.7792),       # Bowie, MD
    ("Chantilly, VA", 38.8790, -77.4426),    # Chantilly, VA
    ("Reston, VA", 38.9587, -77.3570),      # Reston, VA
    ("Manassas, VA", 38.7509, -77.4753)      # Manassas, VA
]

# Function to get placemarks for a specific location
def get_placemarks(api_key, lat, lon, distance=500):
    url = "https://external.transitapp.com/v3/map_layers/placemarks"

    # Set the header with the API Key
    headers = {
        'apiKey': api_key
    }

    params = {
        "lat": lat,
        "lon": lon,
        "distance": distance
    }

    # Make the API request with header
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()  # Return JSON response
    else:
        return {"error": f"Failed to retrieve data: {response.status_code}"}

# CSV file path
csv_file = "placemarks_data.csv"

# Header for the CSV file
csv_headers = ["title", "id", "networkName", "networkId", "color", "textColor", "latitude", "longitude", "type", "location"]

# Open the CSV file in write mode
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(csv_headers)  # Write the header row

    # Fetch placemarks for top 20 DMV locations and write them to the CSV
    for location, lat, lon in locations:
        print(f"Fetching placemarks for {location} (Lat: {lat}, Lon: {lon})...")

        placemarks = get_placemarks(api_key, lat, lon)

        # Check for error or process placemarks data
        if "error" in placemarks:
            print(placemarks["error"])
        else:
            for placemark in placemarks.get('placemarks', []):
                # Write each placemark's data to the CSV
                writer.writerow([
                    placemark.get('title', ''),
                    placemark.get('id', ''),
                    placemark.get('networkName', ''),
                    placemark.get('networkId', ''),
                    placemark.get('color', ''),
                    placemark.get('textColor', ''),
                    placemark.get('latitude', ''),
                    placemark.get('longitude', ''),
                    placemark.get('type', ''),
                    location  # Location name for context
                ])

print(f"Placemark data has been written to {csv_file}")
# Out:
# Fetching placemarks for Washington, DC (Lat: 38.9076, Lon: -77.0365)...
# Fetching placemarks for Bethesda, MD (Lat: 39.004, Lon: -77.089)...
# Fetching placemarks for Silver Spring, MD (Lat: 38.9907, Lon: -77.0261)...
# Fetching placemarks for Arlington, VA (Lat: 38.887, Lon: -77.0941)...
# Fetching placemarks for Alexandria, VA (Lat: 38.8048, Lon: -77.0469)...
# Fetching placemarks for Rockville, MD (Lat: 39.0836, Lon: -77.1528)...
# Fetching placemarks for Gaithersburg, MD (Lat: 39.1434, Lon: -77.2013)...
# Failed to retrieve data: 404
# Fetching placemarks for Tysons, VA (Lat: 38.9277, Lon: -77.221)...
# Failed to retrieve data: 404
# Fetching placemarks for Fairfax, VA (Lat: 38.8462, Lon: -77.3064)...
# Failed to retrieve data: 429
# Fetching placemarks for McLean, VA (Lat: 38.9331, Lon: -77.1793)...
# Failed to retrieve data: 429
# Fetching placemarks for Falls Church, VA (Lat: 38.8816, Lon: -77.1747)...
# Failed to retrieve data: 429
# ...

# %%
df_placemarks = pd.read_csv('placemarks_data.csv')

# %%
df_placemarks.head()
# Out:
#                             title                                    id  \
# 0  17th St / Massachusetts Ave NW  08255063-1f3f-11e7-bf6b-3863bb334450
# 1                  15th / P St NW  0824791a-1f3f-11e7-bf6b-3863bb334450
# 2   14th St / Rhode Island Ave NW  08247a21-1f3f-11e7-bf6b-3863bb334450
# 3                  15th / M St NW  7fcbf92d-a257-4973-828b-181d5602eee5
# 4                  15th / L St NW  0825fc3a-1f3f-11e7-bf6b-3863bb334450
#
#          networkName  networkId   color textColor   latitude  longitude  \
# 0  Capital Bikeshare         12  EE3124    FFFFFF  38.908568 -77.038542
# 1  Capital Bikeshare         12  EE3124    FFFFFF  38.909801 -77.034427
# 2  Capital Bikeshare         12  EE3124    FFFFFF  38.908600 -77.032300
# 3  Capital Bikeshare         12  EE3124    FFFFFF  38.905424 -77.034674
# 4  Capital Bikeshare         12  EE3124    FFFFFF  38.903967 -77.034602
#
#       type        location
# 0  station  Washington, DC
# 1  station  Washington, DC
# ...

# %%
# @title type vs location

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['location'].value_counts()
    for x_label, grp in df_placemarks.groupby('type')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('type')
_ = plt.ylabel('location')

# %%
# @title networkName

from matplotlib import pyplot as plt
import seaborn as sns
df_placemarks.groupby('networkName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Distribution of Placemarks by Network

import matplotlib.pyplot as plt

# Assuming your data is in a pandas DataFrame called 'df_placemarks'
network_counts = df_placemarks['networkName'].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(network_counts.index, network_counts.values)
plt.xlabel('Network Name')
plt.ylabel('Number of Placemarks')
plt.title('Distribution of Placemarks by Network')
_ = plt.xticks(rotation=45, ha='right')

# %%
# @title location

from matplotlib import pyplot as plt
import seaborn as sns
df_placemarks.groupby('location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_placemarks.shape
# Out:
# (443, 10)

# %%
df_placemarks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        443 non-null    object
#  1   id           443 non-null    object
#  2   networkName  443 non-null    object
#  3   networkId    443 non-null    int64
#  4   color        443 non-null    object
#  5   textColor    443 non-null    object
#  6   latitude     443 non-null    float64
#  7   longitude    443 non-null    float64
#  8   type         443 non-null    object
#  9   location     443 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 34.7+ KB

# %%
df_placemarks.describe()
# Out:
#         networkId    latitude   longitude
# count  443.000000  443.000000  443.000000
# mean   558.846501   38.894542  -77.041226
# std    250.513886    0.043476    0.019813
# min     12.000000   38.803180  -77.178408
# 25%    611.000000   38.904195  -77.041072
# 50%    613.000000   38.906327  -77.036482
# 75%    678.000000   38.909291  -77.033749
# max    823.000000   39.086622  -77.023304

# %%
df_placemarks.isnull().sum()
# Out:
# title          0
# id             0
# networkName    0
# networkId      0
# color          0
# textColor      0
# latitude       0
# longitude      0
# type           0
# location       0
# dtype: int64
